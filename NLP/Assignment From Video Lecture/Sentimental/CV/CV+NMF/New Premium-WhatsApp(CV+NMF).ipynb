# %%
import pandas as pd

# %%
# Initialize an empty list to store the lines
lines = []

# Trying to read the file line by line
try:
    with open('mabel.txt', 'r', encoding='utf8') as file:
        for line in file:
            # Trying to append the line to the list
            try:
                lines.append(line)
            except pd.errors.ParserError as e:
                print(f"Error parsing line: {e}")
                # Handling the error as needed
except Exception as e:
    print(f"Error reading file: {e}")

# Converting the list of lines to a DataFrame
df = pd.DataFrame(lines, columns=["text"])
df.head()
# Out:
#                                                 text
# 0  05/12/19, 1:42 pm - Messages to this chat and ...
# 1  05/12/19, 1:42 pm - Mabel Infoziant: Hi this i...
# 2  05/12/19, 1:42 pm - Mabel Infoziant: What’s yo...
# 3          05/12/19, 1:42 pm - AR❤: Ramisha Rani K\n
# 4          05/12/19, 1:42 pm - Mabel Infoziant: Ok\n

# %% [markdown]
# #### Extracting information using regular expressions
# df= df['text'].str.extract(r'(\d{1,2}/\d{1,2}/\d{1,2}), (\d{1,2}:\d{1,2} [apmAPM]+) - ([^:]+): (.+)')
# df.head()

# %% [markdown]
# #### Naming the columns
# df.columns = ['Date', 'Time', 'Name', 'Chat']
# df.head()

# %% [markdown]
# #### Dropping 1st row
# df=df.drop(0)
# df.head()

# %% [markdown]
# # Consolidate Version of Above Codes Below Code 2

# %%
# Extracting information using regular expressions
df= df['text'].str.extract(r'(\d{1,2}/\d{1,2}/\d{1,2}), (\d{1,2}:\d{1,2} [apmAPM]+) - ([^:]+): (.+)')


# Naming the columns
df.columns = ['Date', 'Time', 'Name', 'Chat']

# Dropping 1st row
df=df.drop(0)
df.head()
# Out:
#        Date     Time             Name                            Chat
# 1  05/12/19  1:42 pm  Mabel Infoziant  Hi this is Mabel we just spoke
# 2  05/12/19  1:42 pm  Mabel Infoziant           What’s your full name
# 3  05/12/19  1:42 pm              AR❤                  Ramisha Rani K
# 4  05/12/19  1:42 pm  Mabel Infoziant                              Ok
# 5  05/12/19  1:42 pm  Mabel Infoziant          ramisharanik@gmail.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 1 to 52
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    52 non-null     object
#  1   Time    52 non-null     object
#  2   Name    52 non-null     object
#  3   Chat    52 non-null     object
# dtypes: object(4)
# memory usage: 1.8+ KB

# %%
#pip install nltk

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

dataset.dropna(inplace=True)
dataset.head()
# Out:
#        Date     Time             Name                            Chat
# 1  05/12/19  1:42 pm  Mabel Infoziant  Hi this is Mabel we just spoke
# 2  05/12/19  1:42 pm  Mabel Infoziant           What’s your full name
# 3  05/12/19  1:42 pm              AR❤                  Ramisha Rani K
# 4  05/12/19  1:42 pm  Mabel Infoziant                              Ok
# 5  05/12/19  1:42 pm  Mabel Infoziant          ramisharanik@gmail.com

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/viswanathanmuthu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()
sid

# %%
senti=sid.polarity_scores(dataset['Chat'][4])
senti
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_Senti
# Out:
#         Date      Time             Name  \
# 1   05/12/19   1:42 pm  Mabel Infoziant
# 2   05/12/19   1:42 pm  Mabel Infoziant
# 3   05/12/19   1:42 pm              AR❤
# 4   05/12/19   1:42 pm  Mabel Infoziant
# 5   05/12/19   1:42 pm  Mabel Infoziant
# 6   05/12/19   1:43 pm  Mabel Infoziant
# 7   05/12/19   1:43 pm              AR❤
# 8   05/12/19   1:43 pm  Mabel Infoziant
# 9   05/12/19   1:43 pm              AR❤
# 10  05/12/19   1:43 pm  Mabel Infoziant
# 11  05/12/19   1:43 pm  Mabel Infoziant
# 12  05/12/19   1:44 pm              AR❤
# 13  05/12/19   1:45 pm              AR❤
# 14  05/12/19   1:48 pm  Mabel Infoziant
# 15  05/12/19   1:48 pm  Mabel Infoziant
# 16  05/12/19   1:49 pm              AR❤
# 17  05/12/19   2:00 pm              AR❤
# 18  05/12/19   2:04 pm  Mabel Infoziant
# 19  05/12/19   2:04 pm  Mabel Infoziant
# 20  05/12/19   2:06 pm              AR❤
# 21  05/12/19   2:07 pm              AR❤
# 22  05/12/19   4:20 pm              AR❤
# 23  05/12/19   4:44 pm  Mabel Infoziant
# 24  05/12/19   4:48 pm              AR❤
# 25  05/12/19   8:07 pm              AR❤
# 26  08/12/19  10:45 pm  Mabel Infoziant
# 27  08/12/19  11:52 pm              AR❤
# 28  08/12/19  11:55 pm              AR❤
# 29  09/12/19  12:09 pm              AR❤
# 30  09/12/19  12:13 pm  Mabel Infoziant
# 31  09/12/19  12:23 pm  Mabel Infoziant
# 32  09/12/19  12:25 pm              AR❤
# 33  09/12/19  12:26 pm              AR❤
# 34  09/12/19  12:26 pm              AR❤
# 35  09/12/19  12:28 pm              AR❤
# 36  09/12/19  12:28 pm              AR❤
# 37  09/12/19  12:29 pm              AR❤
# 38  09/12/19  12:41 pm  Mabel Infoziant
# 39  09/12/19  12:42 pm              AR❤
# 40  10/12/19   7:59 am  Mabel Infoziant
# 41  10/12/19   8:00 am  Mabel Infoziant
# 42  10/12/19   8:55 am              AR❤
# 43  12/12/19   2:24 pm              AR❤
# 44  12/12/19   2:26 pm  Mabel Infoziant
# 45  15/12/19   8:22 pm              AR❤
# 46  15/12/19   8:40 pm  Mabel Infoziant
# 47  15/12/19   8:40 pm              AR❤
# 48  18/12/19   3:09 pm              AR❤
# 49  18/12/19   3:09 pm              AR❤
# 50  18/12/19   3:11 pm  Mabel Infoziant
# 51  18/12/19   3:11 pm  Mabel Infoziant
# 52  18/12/19   3:12 pm              AR❤
#
#                                                  Chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11  Send me cbe office address and phone number I ...
# 12    Yeah Mam within Evening I will forward you mam.
# 13  Tomorrow I have to visit the office.yet not I ...
# 14                                                 ok
# 15  send the details of office location once u get...
# 16   Sure mam. Soon I will share details with you mam
# 17  I have read the Abstract mam. We can do mam. N...
# 18  I think Vignesh has the data set will ask him ...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21  I have read both the abstract mam. We can do b...
# 22  I received project details from Vignesh, mam. ...
# 23  Yes we need to ya about amount and all other d...
# 24                                          Sure mam.
# 25                                  Shall I call mam?
# 26         Hi I was at church couldn’t take your call
# 27                                         It's k mam
# 28  Just to know the tomorrow plan mam.will see to...
# 29                    Mam can u send Vignesh number??
# 30           Vignesh ML Infoziant.vcf (file attached)
# 31                           I was in a meeting sorry
# 32                                    Can I cal u mam
# 33  Waiting for u r finalization of rates for our ...
# 34  If we finiliaze I can work with full involveme...
# 35  So what ever may be ..if you think your are co...
# 36                           You deleted this message
# 37                                     Do the needful
# 38  No ma please hold I am in a hot meeting with a...
# 39                                     Ok mam thank u
# 40  Ramisha we need to talk today i will call u ar...
# 41     Be ready to discuss about the ML titles u have
# 42                                           Okay mam
# 43  Mam, I have sent the mail regarding project de...
# 44                                                 ok
# 45                                    Mam are u free?
# 46   Am at church can call very late or tomorrow only
# 47  Kk mam. I will ask Arun brother. Small doubt ....
# 48                                             Hi mam
# 49                                   Any updates mam?
# 50     U might have to start on the WhatsApp analysis
# 51            There is one project that got committed
# 52                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 12  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 16  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'comp...   -0.3400    0.124
# 23  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 24  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 28  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 29  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 31  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 35  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 37  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 38  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 39  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 40  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 41  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 42  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 43  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 44  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 45  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 50  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 51  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 52  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score
# 1     0.000    1.000        pos
# 2     0.000    1.000        pos
# 3     0.000    1.000        pos
# 4     1.000    0.000        pos
# 5     0.000    1.000        pos
# 6     0.000    1.000        pos
# 7     0.730    0.270        pos
# 8     0.000    1.000        pos
# 9     0.688    0.312        pos
# 10    0.000    1.000        pos
# 11    0.085    0.915        pos
# 12    0.239    0.761        pos
# 13    0.000    1.000        pos
# 14    1.000    0.000        pos
# 15    0.104    0.896        pos
# 16    0.391    0.609        pos
# 17    0.000    1.000        pos
# 18    0.000    1.000        pos
# 19    0.000    1.000        pos
# 20    0.688    0.312        pos
# 21    0.000    1.000        pos
# 22    0.000    0.876        neg
# 23    0.162    0.838        pos
# 24    0.697    0.303        pos
# 25    0.000    1.000        pos
# 26    0.000    1.000        pos
# 27    0.000    1.000        pos
# 28    0.225    0.775        pos
# 29    0.293    0.707        pos
# 30    0.000    1.000        pos
# 31    0.000    0.698        neg
# 32    0.000    1.000        pos
# 33    0.000    1.000        pos
# 34    0.000    1.000        pos
# 35    0.125    0.875        pos
# 36    0.000    1.000        pos
# 37    0.000    1.000        pos
# 38    0.089    0.736        neg
# 39    0.825    0.175        pos
# 40    0.000    1.000        pos
# 41    0.238    0.762        pos
# 42    0.655    0.345        pos
# 43    0.000    1.000        pos
# 44    1.000    0.000        pos
# 45    0.623    0.377        pos
# 46    0.000    1.000        pos
# 47    0.270    0.619        pos
# 48    0.000    1.000        pos
# 49    0.000    1.000        pos
# 50    0.000    1.000        pos
# 51    0.259    0.741        pos
# 52    0.714    0.286        pos

# %%
pos
# Out:
#             count
# comp_score
# pos            49
# neg             3

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Creating a CountVectorizer
cv=CountVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=cv.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF

# Fitting an NMF model
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)
# Out:
# NMF(n_components=5, random_state=42)

# %%
# Displaying top words for each topic
for index,topic in enumerate(nmf_model.components_):
    results=([cv.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['hi', 'soon', 'ok', 'sure', 'ask', 'yeah', 'kk', 'read', 'abstract', 'mam']
# ['start', 'think', 'know', 'vignesh', 'ask', 'students', 'phone', 'office', 'number', 'send']
# ['ml', 'send', 'abstracts', 'finiliaze', 'think', 'vignesh', 'mam', 'details', 'sent', 'project']
# ['meeting', 'ml', 'need', 'mam', 'hi', 'church', 'office', 'know', 'just', 'tomorrow']
# ['phone', 'students', 'ramisha', 'know', 'sure', 'yes', 'soon', 'share', 'need', 'details']

# %%
# Transforming the data to get topic results
topic_results=nmf_model.transform(dtm)

# Assignning topics to the DataFrame
df["Topic"]=topic_results.argmax(axis=1)
df
# Out:
#         Date      Time             Name  \
# 1   05/12/19   1:42 pm  Mabel Infoziant
# 2   05/12/19   1:42 pm  Mabel Infoziant
# 3   05/12/19   1:42 pm              AR❤
# 4   05/12/19   1:42 pm  Mabel Infoziant
# 5   05/12/19   1:42 pm  Mabel Infoziant
# 6   05/12/19   1:43 pm  Mabel Infoziant
# 7   05/12/19   1:43 pm              AR❤
# 8   05/12/19   1:43 pm  Mabel Infoziant
# 9   05/12/19   1:43 pm              AR❤
# 10  05/12/19   1:43 pm  Mabel Infoziant
# 11  05/12/19   1:43 pm  Mabel Infoziant
# 12  05/12/19   1:44 pm              AR❤
# 13  05/12/19   1:45 pm              AR❤
# 14  05/12/19   1:48 pm  Mabel Infoziant
# 15  05/12/19   1:48 pm  Mabel Infoziant
# 16  05/12/19   1:49 pm              AR❤
# 17  05/12/19   2:00 pm              AR❤
# 18  05/12/19   2:04 pm  Mabel Infoziant
# 19  05/12/19   2:04 pm  Mabel Infoziant
# 20  05/12/19   2:06 pm              AR❤
# 21  05/12/19   2:07 pm              AR❤
# 22  05/12/19   4:20 pm              AR❤
# 23  05/12/19   4:44 pm  Mabel Infoziant
# 24  05/12/19   4:48 pm              AR❤
# 25  05/12/19   8:07 pm              AR❤
# 26  08/12/19  10:45 pm  Mabel Infoziant
# 27  08/12/19  11:52 pm              AR❤
# 28  08/12/19  11:55 pm              AR❤
# 29  09/12/19  12:09 pm              AR❤
# 30  09/12/19  12:13 pm  Mabel Infoziant
# 31  09/12/19  12:23 pm  Mabel Infoziant
# 32  09/12/19  12:25 pm              AR❤
# 33  09/12/19  12:26 pm              AR❤
# 34  09/12/19  12:26 pm              AR❤
# 35  09/12/19  12:28 pm              AR❤
# 36  09/12/19  12:28 pm              AR❤
# 37  09/12/19  12:29 pm              AR❤
# 38  09/12/19  12:41 pm  Mabel Infoziant
# 39  09/12/19  12:42 pm              AR❤
# 40  10/12/19   7:59 am  Mabel Infoziant
# 41  10/12/19   8:00 am  Mabel Infoziant
# 42  10/12/19   8:55 am              AR❤
# 43  12/12/19   2:24 pm              AR❤
# 44  12/12/19   2:26 pm  Mabel Infoziant
# 45  15/12/19   8:22 pm              AR❤
# 46  15/12/19   8:40 pm  Mabel Infoziant
# 47  15/12/19   8:40 pm              AR❤
# 48  18/12/19   3:09 pm              AR❤
# 49  18/12/19   3:09 pm              AR❤
# 50  18/12/19   3:11 pm  Mabel Infoziant
# 51  18/12/19   3:11 pm  Mabel Infoziant
# 52  18/12/19   3:12 pm              AR❤
#
#                                                  Chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11  Send me cbe office address and phone number I ...
# 12    Yeah Mam within Evening I will forward you mam.
# 13  Tomorrow I have to visit the office.yet not I ...
# 14                                                 ok
# 15  send the details of office location once u get...
# 16   Sure mam. Soon I will share details with you mam
# 17  I have read the Abstract mam. We can do mam. N...
# 18  I think Vignesh has the data set will ask him ...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21  I have read both the abstract mam. We can do b...
# 22  I received project details from Vignesh, mam. ...
# 23  Yes we need to ya about amount and all other d...
# 24                                          Sure mam.
# 25                                  Shall I call mam?
# 26         Hi I was at church couldn’t take your call
# 27                                         It's k mam
# 28  Just to know the tomorrow plan mam.will see to...
# 29                    Mam can u send Vignesh number??
# 30           Vignesh ML Infoziant.vcf (file attached)
# 31                           I was in a meeting sorry
# 32                                    Can I cal u mam
# 33  Waiting for u r finalization of rates for our ...
# 34  If we finiliaze I can work with full involveme...
# 35  So what ever may be ..if you think your are co...
# 36                           You deleted this message
# 37                                     Do the needful
# 38  No ma please hold I am in a hot meeting with a...
# 39                                     Ok mam thank u
# 40  Ramisha we need to talk today i will call u ar...
# 41     Be ready to discuss about the ML titles u have
# 42                                           Okay mam
# 43  Mam, I have sent the mail regarding project de...
# 44                                                 ok
# 45                                    Mam are u free?
# 46   Am at church can call very late or tomorrow only
# 47  Kk mam. I will ask Arun brother. Small doubt ....
# 48                                             Hi mam
# 49                                   Any updates mam?
# 50     U might have to start on the WhatsApp analysis
# 51            There is one project that got committed
# 52                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 12  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 16  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'comp...   -0.3400    0.124
# 23  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 24  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 28  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 29  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 31  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 35  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 37  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 38  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 39  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 40  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 41  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 42  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 43  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 44  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 45  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 50  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 51  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 52  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score  Topic
# 1     0.000    1.000        pos      3
# 2     0.000    1.000        pos      0
# 3     0.000    1.000        pos      4
# 4     1.000    0.000        pos      0
# 5     0.000    1.000        pos      0
# 6     0.000    1.000        pos      0
# 7     0.730    0.270        pos      0
# 8     0.000    1.000        pos      1
# 9     0.688    0.312        pos      0
# 10    0.000    1.000        pos      0
# 11    0.085    0.915        pos      1
# 12    0.239    0.761        pos      0
# 13    0.000    1.000        pos      3
# 14    1.000    0.000        pos      0
# 15    0.104    0.896        pos      4
# 16    0.391    0.609        pos      4
# 17    0.000    1.000        pos      0
# 18    0.000    1.000        pos      1
# 19    0.000    1.000        pos      2
# 20    0.688    0.312        pos      0
# 21    0.000    1.000        pos      0
# 22    0.000    0.876        neg      2
# 23    0.162    0.838        pos      4
# 24    0.697    0.303        pos      0
# 25    0.000    1.000        pos      0
# 26    0.000    1.000        pos      3
# 27    0.000    1.000        pos      0
# 28    0.225    0.775        pos      3
# 29    0.293    0.707        pos      1
# 30    0.000    1.000        pos      2
# 31    0.000    0.698        neg      4
# 32    0.000    1.000        pos      0
# 33    0.000    1.000        pos      0
# 34    0.000    1.000        pos      2
# 35    0.125    0.875        pos      2
# 36    0.000    1.000        pos      0
# 37    0.000    1.000        pos      0
# 38    0.089    0.736        neg      4
# 39    0.825    0.175        pos      0
# 40    0.000    1.000        pos      4
# 41    0.238    0.762        pos      2
# 42    0.655    0.345        pos      0
# 43    0.000    1.000        pos      2
# 44    1.000    0.000        pos      0
# 45    0.623    0.377        pos      0
# 46    0.000    1.000        pos      3
# 47    0.270    0.619        pos      0
# 48    0.000    1.000        pos      0
# 49    0.000    1.000        pos      0
# 50    0.000    1.000        pos      1
# 51    0.259    0.741        pos      2
# 52    0.714    0.286        pos      0

# %%
df["Topic"].value_counts()
# Out:
# Topic
# 0    27
# 2     8
# 4     7
# 3     5
# 1     5
# Name: count, dtype: int64

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/viswanathanmuthu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
comment_words = []
stoplist = stopwords.words('english')
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
wordcloudss="This function saves image"
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    vv=" ".join(comment_words)          
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)         
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('wordcloud.PNG')
plt.show() 
print("Successfully created")
wordcloudss="This function saves image"
# Out:
# Successfully created
