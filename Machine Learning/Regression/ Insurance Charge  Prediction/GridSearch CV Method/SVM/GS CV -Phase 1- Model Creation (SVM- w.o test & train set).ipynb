# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Insurance_Prediction.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[["charges"]]

# %% [markdown]
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)
# X_train

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# X_train=sc.fit_transform(X_train)
# X_test=sc.transform(X_test)
# X_train

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[1000,2000,3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ..C=1000, gamma=auto, kernel=poly;, score=-9.893 total time=10.8min
# [CV 5/5] END .C=2000, gamma=auto, kernel=poly;, score=-48.410 total time=18.6min
# [CV 1/5] END C=3000, gamma=auto, kernel=sigmoid;, score=-0.115 total time=   0.1s
# [CV 2/5] END C=3000, gamma=auto, kernel=sigmoid;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=3000, gamma=auto, kernel=sigmoid;, score=-0.082 total time=   0.0s
# [CV 4/5] END C=3000, gamma=auto, kernel=sigmoid;, score=-0.106 total time=   0.0s
# [CV 5/5] END C=3000, gamma=auto, kernel=sigmoid;, score=-0.107 total time=   0.1s
# [CV 1/5] END .C=3000, gamma=auto, kernel=linear;, score=0.678 total time=   1.5s
# [CV 2/5] END .C=3000, gamma=auto, kernel=linear;, score=0.627 total time=   1.1s
# [CV 3/5] END .C=3000, gamma=auto, kernel=linear;, score=0.733 total time=   1.1s
# [CV 4/5] END .C=3000, gamma=auto, kernel=linear;, score=0.633 total time=   2.0s
# [CV 5/5] END .C=3000, gamma=auto, kernel=linear;, score=0.699 total time=   1.4s
# [CV 1/5] END ..C=3000, gamma=scale, kernel=rbf;, score=-0.129 total time=   0.1s
# [CV 2/5] END ..C=3000, gamma=scale, kernel=rbf;, score=-0.076 total time=   0.1s
# [CV 3/5] END ..C=3000, gamma=scale, kernel=rbf;, score=-0.100 total time=   0.1s
# [CV 4/5] END ..C=3000, gamma=scale, kernel=rbf;, score=-0.116 total time=   0.1s
# [CV 5/5] END ..C=3000, gamma=scale, kernel=rbf;, score=-0.179 total time=   0.1s
# [CV 1/5] END ..C=3000, gamma=scale, kernel=poly;, score=0.038 total time=   0.1s
# [CV 2/5] END ..C=3000, gamma=scale, kernel=poly;, score=0.098 total time=   0.1s
# [CV 3/5] END ..C=3000, gamma=scale, kernel=poly;, score=0.049 total time=   0.1s
# [CV 4/5] END ..C=3000, gamma=scale, kernel=poly;, score=0.036 total time=   0.1s
# [CV 5/5] END .C=3000, gamma=scale, kernel=poly;, score=-0.021 total time=   0.1s
# [CV 1/5] END C=3000, gamma=scale, kernel=sigmoid;, score=-15.562 total time=   0.1s
# [CV 2/5] END C=3000, gamma=scale, kernel=sigmoid;, score=-20.499 total time=   0.1s
# [CV 3/5] END C=3000, gamma=scale, kernel=sigmoid;, score=-17.095 total time=   0.1s
# [CV 4/5] END C=3000, gamma=scale, kernel=sigmoid;, score=-16.751 total time=   0.1s
# [CV 5/5] END C=3000, gamma=scale, kernel=sigmoid;, score=-15.012 total time=   0.1s
# [CV 1/5] END C=3000, gamma=scale, kernel=linear;, score=0.678 total time=   1.5s
# [CV 2/5] END C=3000, gamma=scale, kernel=linear;, score=0.627 total time=   1.1s
# [CV 3/5] END C=3000, gamma=scale, kernel=linear;, score=0.733 total time=   1.1s
# [CV 4/5] END C=3000, gamma=scale, kernel=linear;, score=0.633 total time=   2.0s
# [CV 5/5] END C=3000, gamma=scale, kernel=linear;, score=0.699 total time=   1.3s
# [CV 2/5] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.054 total time=   0.1s
# [CV 2/5] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.082 total time=   0.1s
# [CV 2/5] END .C=1000, gamma=auto, kernel=linear;, score=0.675 total time=   0.3s
# [CV 5/5] END .C=1000, gamma=auto, kernel=linear;, score=0.678 total time=   0.4s
# [CV 5/5] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.206 total time=   0.1s
# [CV 3/5] END .C=1000, gamma=scale, kernel=poly;, score=-0.073 total time=   0.1s
# [CV 1/5] END C=1000, gamma=scale, kernel=sigmoid;, score=-2.043 total time=   0.1s
# [CV 4/5] END C=1000, gamma=scale, kernel=sigmoid;, score=-2.211 total time=   0.1s
# [CV 2/5] END C=1000, gamma=scale, kernel=linear;, score=0.675 total time=   0.3s
# [CV 5/5] END C=1000, gamma=scale, kernel=linear;, score=0.678 total time=   0.4s
# [CV 5/5] END ...C=2000, gamma=auto, kernel=rbf;, score=-0.067 total time=   0.1s
# [CV 3/5] END .C=2000, gamma=auto, kernel=poly;, score=-27.650 total time=15.7min
# [CV 2/5] END C=3000, gamma=auto, kernel=poly;, score=-103.740 total time=19.6min
# [CV 3/5] END .C=1000, gamma=auto, kernel=poly;, score=-13.667 total time=27.8min
# [CV 5/5] END C=3000, gamma=auto, kernel=poly;, score=-121.886 total time=10.8min
# [CV 5/5] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.118 total time=   0.1s
# [CV 1/5] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.106 total time=   0.0s
# [CV 5/5] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.107 total time=   0.0s
# [CV 3/5] END .C=1000, gamma=auto, kernel=linear;, score=0.680 total time=   0.4s
# [CV 1/5] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.155 total time=   0.1s
# [CV 2/5] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.098 total time=   0.1s
# [CV 3/5] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.124 total time=   0.1s
# [CV 4/5] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.137 total time=   0.1s
# [CV 2/5] END .C=1000, gamma=scale, kernel=poly;, score=-0.028 total time=   0.1s
# [CV 5/5] END .C=1000, gamma=scale, kernel=poly;, score=-0.134 total time=   0.1s
# [CV 2/5] END C=1000, gamma=scale, kernel=sigmoid;, score=-2.686 total time=   0.1s
# [CV 5/5] END C=1000, gamma=scale, kernel=sigmoid;, score=-1.943 total time=   0.1s
# [CV 3/5] END C=1000, gamma=scale, kernel=linear;, score=0.680 total time=   0.3s
# [CV 1/5] END ...C=2000, gamma=auto, kernel=rbf;, score=-0.033 total time=   0.1s
# [CV 2/5] END ...C=2000, gamma=auto, kernel=rbf;, score=-0.003 total time=   0.1s
# [CV 3/5] END ...C=2000, gamma=auto, kernel=rbf;, score=-0.027 total time=   0.1s
# [CV 4/5] END ...C=2000, gamma=auto, kernel=rbf;, score=-0.029 total time=   0.1s
# [CV 1/5] END .C=2000, gamma=auto, kernel=poly;, score=-35.491 total time=13.9min
# [CV 1/5] END C=2000, gamma=auto, kernel=sigmoid;, score=-0.115 total time=   0.0s
# [CV 2/5] END C=2000, gamma=auto, kernel=sigmoid;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=2000, gamma=auto, kernel=sigmoid;, score=-0.082 total time=   0.0s
# [CV 4/5] END C=2000, gamma=auto, kernel=sigmoid;, score=-0.106 total time=   0.0s
# [CV 5/5] END C=2000, gamma=auto, kernel=sigmoid;, score=-0.107 total time=   0.0s
# [CV 1/5] END .C=2000, gamma=auto, kernel=linear;, score=0.682 total time=   0.7s
# [CV 2/5] END .C=2000, gamma=auto, kernel=linear;, score=0.631 total time=   0.8s
# [CV 3/5] END .C=2000, gamma=auto, kernel=linear;, score=0.751 total time=   0.8s
# [CV 4/5] END .C=2000, gamma=auto, kernel=linear;, score=0.646 total time=   0.8s
# [CV 5/5] END .C=2000, gamma=auto, kernel=linear;, score=0.722 total time=   0.7s
# [CV 1/5] END ..C=2000, gamma=scale, kernel=rbf;, score=-0.144 total time=   0.1s
# [CV 2/5] END ..C=2000, gamma=scale, kernel=rbf;, score=-0.088 total time=   0.1s
# [CV 3/5] END ..C=2000, gamma=scale, kernel=rbf;, score=-0.113 total time=   0.1s
# [CV 4/5] END ..C=2000, gamma=scale, kernel=rbf;, score=-0.129 total time=   0.1s
# [CV 5/5] END ..C=2000, gamma=scale, kernel=rbf;, score=-0.194 total time=   0.1s
# [CV 1/5] END .C=2000, gamma=scale, kernel=poly;, score=-0.021 total time=   0.1s
# [CV 2/5] END ..C=2000, gamma=scale, kernel=poly;, score=0.036 total time=   0.1s
# [CV 3/5] END .C=2000, gamma=scale, kernel=poly;, score=-0.011 total time=   0.1s
# [CV 4/5] END .C=2000, gamma=scale, kernel=poly;, score=-0.025 total time=   0.1s
# [CV 5/5] END .C=2000, gamma=scale, kernel=poly;, score=-0.076 total time=   0.1s
# [CV 1/5] END C=2000, gamma=scale, kernel=sigmoid;, score=-7.209 total time=   0.1s
# [CV 2/5] END C=2000, gamma=scale, kernel=sigmoid;, score=-9.283 total time=   0.1s
# [CV 3/5] END C=2000, gamma=scale, kernel=sigmoid;, score=-7.777 total time=   0.1s
# [CV 4/5] END C=2000, gamma=scale, kernel=sigmoid;, score=-7.745 total time=   0.1s
# [CV 5/5] END C=2000, gamma=scale, kernel=sigmoid;, score=-6.892 total time=   0.1s
# [CV 1/5] END C=2000, gamma=scale, kernel=linear;, score=0.682 total time=   0.7s
# [CV 2/5] END C=2000, gamma=scale, kernel=linear;, score=0.631 total time=   0.6s
# [CV 3/5] END C=2000, gamma=scale, kernel=linear;, score=0.751 total time=   0.8s
# [CV 4/5] END C=2000, gamma=scale, kernel=linear;, score=0.646 total time=   1.0s
# [CV 5/5] END C=2000, gamma=scale, kernel=linear;, score=0.722 total time=   0.7s
# [CV 1/5] END ....C=3000, gamma=auto, kernel=rbf;, score=0.012 total time=   0.1s
# [CV 2/5] END ....C=3000, gamma=auto, kernel=rbf;, score=0.044 total time=   0.1s
# [CV 3/5] END ....C=3000, gamma=auto, kernel=rbf;, score=0.013 total time=   0.1s
# [CV 4/5] END ....C=3000, gamma=auto, kernel=rbf;, score=0.022 total time=   0.1s
# [CV 5/5] END ...C=3000, gamma=auto, kernel=rbf;, score=-0.013 total time=   0.1s
# [CV 1/5] END C=3000, gamma=auto, kernel=poly;, score=-135.645 total time=24.9min
# [CV 3/5] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.063 total time=   0.1s
# [CV 1/5] END .C=1000, gamma=auto, kernel=linear;, score=0.736 total time=   0.3s
# [CV 4/5] END .C=1000, gamma=auto, kernel=linear;, score=0.699 total time=   0.4s
# [CV 1/5] END .C=1000, gamma=scale, kernel=poly;, score=-0.081 total time=   0.1s
# [CV 4/5] END .C=1000, gamma=scale, kernel=poly;, score=-0.087 total time=   0.1s
# [CV 3/5] END C=1000, gamma=scale, kernel=sigmoid;, score=-2.195 total time=   0.1s
# [CV 1/5] END C=1000, gamma=scale, kernel=linear;, score=0.736 total time=   0.3s
# [CV 4/5] END C=1000, gamma=scale, kernel=linear;, score=0.699 total time=   0.4s
# [CV 2/5] END .C=2000, gamma=auto, kernel=poly;, score=-72.103 total time=39.3min
# [CV 1/5] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.081 total time=   0.1s
# [CV 4/5] END .C=1000, gamma=auto, kernel=poly;, score=-15.061 total time=21.3min
# [CV 4/5] END .C=3000, gamma=auto, kernel=poly;, score=-99.903 total time=19.1min
# [CV 2/5] END ..C=1000, gamma=auto, kernel=poly;, score=-8.402 total time=16.2min
# [CV 3/5] END C=3000, gamma=auto, kernel=poly;, score=-112.083 total time=27.2min
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1000, 2000, 3000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
#grid_predictions=grid.predict(X_test)
#from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.053373      0.005320         0.019894        0.003757    1000
# 1     1042.325682    390.987140         0.013916        0.007526    1000
# 2        0.041986      0.013416         0.005960        0.003222    1000
# 3        0.359850      0.043085         0.007204        0.007613    1000
# 4        0.056511      0.011930         0.020634        0.005501    1000
# 5        0.058890      0.008422         0.005351        0.002167    1000
# 6        0.051926      0.004006         0.010941        0.003332    1000
# 7        0.359129      0.041502         0.006041        0.002641    1000
# 8        0.066573      0.007874         0.017529        0.003425    2000
# 9     1549.067336    722.956048         0.011896        0.002250    2000
# 10       0.036437      0.003316         0.008190        0.004865    2000
# 11       0.741728      0.080808         0.005984        0.001375    2000
# 12       0.055599      0.004013         0.020738        0.000596    2000
# 13       0.077129      0.007473         0.006556        0.002730    2000
# 14       0.059155      0.003732         0.013499        0.007303    2000
# 15       0.752078      0.116619         0.007902        0.002268    2000
# 16       0.092019      0.008351         0.023088        0.005067    3000
# 17    1219.005922    340.848254         0.009757        0.002816    3000
# 18       0.040538      0.001344         0.007522        0.001387    3000
# 19       1.438217      0.341634         0.006820        0.002167    3000
# 20       0.062554      0.003828         0.021805        0.000930    3000
# 21       0.099749      0.008986         0.008404        0.002221    3000
# 22       0.059413      0.000705         0.010909        0.001823    3000
# 23       1.393285      0.330179         0.006595        0.002227    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
#
#                                                params  split0_test_score  \
# 0       {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.080692
# 1      {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}          -9.892843
# 2   {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 3    {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 4      {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 5     {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}          -0.080527
# 6   {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 7   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 8       {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.033126
# 9      {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}         -35.490805
# 10  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 11   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 12     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143510
# 13    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}          -0.020567
# 14  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 15  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 16      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.011741
# 17     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}        -135.644548
# 18  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 19   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.677778
# 20     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.128958
# 21    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.037700
# 22  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...         -15.561853
# 23  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.054347          -0.062876          -0.079329
# 1           -8.401955         -13.666641         -15.061022
# 2           -0.113567          -0.081608          -0.106067
# 3            0.675162           0.680002           0.699377
# 4           -0.098267          -0.123724          -0.137137
# 5           -0.028469          -0.073376          -0.086611
# 6           -2.686121          -2.194563          -2.210858
# 7            0.675162           0.680002           0.699377
# 8           -0.002835          -0.026545          -0.029140
# 9          -72.102527         -27.649827         -56.548903
# 10          -0.113567          -0.081608          -0.106067
# 11           0.630642           0.750714           0.646368
# 12          -0.087595          -0.113312          -0.128591
# 13           0.035685          -0.011468          -0.024587
# 14          -9.282940          -7.776578          -7.745074
# 15           0.630642           0.750714           0.646368
# 16           0.043659           0.013383           0.021694
# 17        -103.740263        -112.083012         -99.903000
# 18          -0.113567          -0.081608          -0.106067
# 19           0.626814           0.732806           0.633479
# 20          -0.075578          -0.100199          -0.116051
# 21           0.098496           0.049291           0.035615
# 22         -20.498908         -17.095474         -16.750877
# 23           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.117983        -0.079045        0.021865               11
# 1           -9.657986       -11.336090        2.561825               21
# 2           -0.107195        -0.104753        0.012107               13
# 3            0.677952         0.693778        0.022955                1
# 4           -0.206405        -0.144193        0.036262               18
# 5           -0.134493        -0.080695        0.033795               12
# 6           -1.942521        -2.215441        0.255409               19
# 7            0.677952         0.693778        0.022955                1
# 8           -0.067392        -0.031808        0.020699               10
# 9          -48.410424       -48.040497       15.651104               23
# 10          -0.107195        -0.104753        0.012107               13
# 11           0.722261         0.686467        0.045056                3
# 12          -0.193992        -0.133400        0.035492               17
# 13          -0.076360        -0.019459        0.035693                9
# 14          -6.891719        -7.781126        0.821557               20
# 15           0.722261         0.686467        0.045056                3
# 16          -0.012948         0.015506        0.018217                8
# 17        -121.886074      -114.651379       12.932267               24
# 18          -0.107195        -0.104753        0.012107               13
# 19           0.698692         0.673914        0.039876                5
# 20          -0.179304        -0.120018        0.034578               16
# 21          -0.020924         0.040035        0.038064                7
# 22         -15.012168       -16.983856        1.914783               22
# 23           0.698692         0.673914        0.039876                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# [CV 4/5] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.079 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=auto, kernel=poly;, score=-9.658 total time=10.7min
# [CV 4/5] END .C=2000, gamma=auto, kernel=poly;, score=-56.549 total time=41.5min
# Age:33
# BMI:34
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[5314.78817516]
# /Users/viswanathanmuthu/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %% [markdown]
# from sklearn.svm import SVR
# regressor=SVR()
# regressor.fit(X_train,y_train)

# %% [markdown]
# regressor.intercept_

# %% [markdown]
# regressor.n_support_

# %% [markdown]
# regressor.support_

# %% [markdown]
# y_pred=regressor.predict(X_test)

# %% [markdown]
# from sklearn.metrics import r2_score
# r_score=r2_score(y_test,y_pred)

# %% [markdown]
# r_score

# %% [markdown]
# import pickle
# filename="finalized_model_Support_Vector_Machine.sav"
# pickle.dump(regressor,open(filename,'wb'))

# %% [markdown]
# loaded_model=pickle.load(open("finalized_model_Support_Vector_Machine.sav",'rb'))
# result=loaded_model.predict([[33,37,1,1,0]])

# %% [markdown]
# result
