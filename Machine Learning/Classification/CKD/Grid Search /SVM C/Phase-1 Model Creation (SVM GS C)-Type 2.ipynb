# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset['sg'].unique()
# Out:
# array(['c', 'a', 'd', 'b', 'e'], dtype=object)

# %%
enc=OrdinalEncoder()

# %%
enc.fit_transform(dataset[['sg']])
# Out:
# array([[2.],
#        [2.],
#        [0.],
#        [3.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [2.],
#        [3.],
#        [0.],
#        [3.],
#        [0.],
#        [1.],
#        [2.],
#        [3.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [3.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [3.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [3.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [3.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [3.],
#        [0.],
#        [0.],
#        [0.],
#        [3.],
#        [1.],
# ...

# %%
dataset[['sg']]=enc.fit_transform(dataset[['sg']])
dataset
# Out:
#            age         bp   sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  2.0  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  2.0  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  0.0  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  3.0  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  2.0  0.0  0.0  normal    normal  notpresent
# ..         ...        ...  ...  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  0.0  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  2.0  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  2.0  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  0.0  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  0.0  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#            age         bp   sg   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  2.0  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  0.0  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  3.0  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  2.0  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  2.0  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  2.0  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  0.0  100.000000   49.000000  1.000000
#
# ...

# %%
indep=dataset[["age","bp",'sg',"al","su","bgr",'bu','sc','sod','pot','hrmo',"pcv","wc","rc","rbc_normal","pc_normal","pcc_present","ba_present","htn_yes","dm_yes","cad_yes","appet_yes","pe_yes",'ane_yes']]
dep=dataset["classification_yes"]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 
grid = GridSearchCV(SVC(probability=False), param_grid, refit = True, verbose = 3,cv=5,n_jobs=-1,scoring='f1_weighted') 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test) 
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[49  2]
#  [ 3 79]]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        51
#            1       0.98      0.96      0.97        82
#
#     accuracy                           0.96       133
#    macro avg       0.96      0.96      0.96       133
# weighted avg       0.96      0.96      0.96       133

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}: 0.9624731911379498

# %%
from sklearn.metrics import roc_auc_score
y_scores = grid.decision_function(X_test)
roc_auc_score=roc_auc_score(y_test,y_scores)
print("The roc_auc_score is:",roc_auc_score)
# Out:
# The roc_auc_score is: 0.996652319464371

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.001481      0.000998         0.001364        0.001011      10
# 1        0.001786      0.002035         0.001021        0.000411      10
# 2        0.001308      0.000787         0.000859        0.000185      10
# 3        0.001375      0.000549         0.001447        0.000688      10
# 4        0.001892      0.000652         0.001607        0.000451      10
# 5        0.001771      0.000638         0.001792        0.001036      10
# 6        0.001576      0.000640         0.001547        0.001090      10
# 7        0.001375      0.000534         0.001158        0.000628      10
# 8        0.000656      0.000074         0.000540        0.000051     100
# 9        0.000605      0.000095         0.000685        0.000071     100
# 10       0.000974      0.000205         0.000629        0.000048     100
# 11       0.000706      0.000120         0.000577        0.000053     100
# ...

# %%
age_input=float(input("Age:"))
bp_input=float(input("BP:"))
sg_input=float(input("SG 0 or 1 or 2 or 3 or 4:"))
al_input=float(input("AL:"))
su_input=float(input("SU:"))
bgr_input=float(input("BGR:"))
bu_input=float(input("BU:"))
sc_input=float(input("SC:"))
sod_input=float(input("SOD:"))
pot_input=float(input("POT:"))
hrmo_input=float(input("HRMO:"))
pcv_input=float(input("PCV:"))
wc_input=float(input("WC:"))
rc_input=float(input("RC:"))
rbc_normal_input=int(input("RBC Normal 0 or 1:"))
pc_normal_input=int(input("PC Normal 0 or 1:"))
pcc_present_input=int(input("PCC Present 0 or 1:"))
ba_present_input=int(input("BA Present 0 or 1:"))
htn_yes_input=int(input("HTN Yes 0 or 1:"))
dm_yes_input=int(input("DM Yes 0 or 1:"))
cad_yes_input=int(input("CAD Yes or No:"))
appet_yes_input=int(input("APPET Yes 0 or 1:"))
pe_yes_input=int(input("PE Yes or No:"))
ane_yes_input=int(input("ANE Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bp_input,sg_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,rc_input,rbc_normal_input,pc_normal_input,pcc_present_input,ba_present_input,htn_yes_input,dm_yes_input,cad_yes_input,appet_yes_input,pe_yes_input,ane_yes_input]])
y=("Future_Prediction={}".format(Future_Prediction))
if (y==0):
    print("Future_Prediction=[No]")
else:
    print('Future_Prediction=[Yes]')

# %% [markdown]
# Future_Prediction=grid.predict([[40,90,1,2,2,208,111,5,127,4,13,51,1100,6.1,1,1,0,1,0,0,0,1,0,1]])
# print("Future_Prediction={}".format(Future_Prediction)

# %% [markdown]
# Note : got attribute error-predict_proba is not available when  probability=False
#  while running roc_auc _score.
#
# Solution: Used Decision Function Instead (If you don't want to or can't change the probability setting during training, you can use the decision_function method of the SVM classifier to obtain decision values, which can be used to calculate ROC AUC scores. The decision values are not probabilities but can still be used for ranking predictions.)
#
# from sklearn.model_selection import GridSearchCV
# svm = SVC(probability=False)
# param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
#              'gamma':['auto','scale'],
#              'C':[10,100,1000,2000,3000]}
# grid = GridSearchCV(svm, param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')
# grid.fit(X_train, y_train)
#
# from sklearn.metrics import roc_auc_score
# y_scores = grid.decision_function(X_test)
# roc_auc_score=roc_auc_score(y_test,y_scores)
# print("The roc_auc_score is:",roc_auc_score)
# ![Attribute%20error.png](attachment:Attribute%20error.png)
