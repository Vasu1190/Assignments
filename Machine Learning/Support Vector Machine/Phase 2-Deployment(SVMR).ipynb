# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Support_Vector_Machine.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])

# %%
result
# Out:
# array([72456064.71514185])
