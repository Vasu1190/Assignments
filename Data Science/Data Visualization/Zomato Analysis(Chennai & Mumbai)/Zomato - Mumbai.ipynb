# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'svg'

# %%
dataset= pd.read_csv('Zomato_Mumbai_Dataset.csv', delimiter='|')
dataset
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# ...

# %% [markdown]
# # Getting Basic Information about the Dataset

# %%
dataset.shape
# Out:
# (15081, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             15081 non-null  object
#  1   PRICE            15080 non-null  object
#  2   CUSINE_CATEGORY  15079 non-null  object
#  3   CITY             15080 non-null  object
#  4   REGION           15080 non-null  object
#  5   URL              15080 non-null  object
#  6   PAGE NO          15080 non-null  object
#  7   CUSINE TYPE      15080 non-null  object
#  8   TIMING           15015 non-null  object
#  9   RATING_TYPE      14070 non-null  object
#  10  RATING           15080 non-null  object
#  11  VOTES            15080 non-null  object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %%
dataset.describe()
# Out:
#          NAME  PRICE  CUSINE_CATEGORY    CITY  REGION    URL  PAGE NO  \
# count   15081  15080            15079   15080   15080  15080    15080
# unique  12720     67             3183       2     241  13823      944
# top      NAME    400  CUSINE_CATEGORY  Mumbai  REGION    URL  PAGE NO
# freq      942   2042              942   14138     942    942      942
#
#         CUSINE TYPE                 TIMING RATING_TYPE RATING  VOTES
# count         15080                  15015       14070  15080  15080
# unique           23                   2551          31     35   1124
# top     Quick Bites  11am to 11pm(Mon-Sun)     Average      -      -
# freq           5262                   1192        5112   2360   2360

# %% [markdown]
# # Dataset Cleaning
#
# ### 1. Removing the redundunt rows of data
# ### 2. Removing the Null Records
# ### 3. Converting the DataTypes of numerical columns to numeric dataype
# ### 4. Working with 'Timing' column
# ### 5. Removing the restaurant records whose Rating or Votes is 0
# ### 6. Working on 'RATING_TYPE' Column
# ### 7. Working on 'REGION' Column
# ### 8. Removing Duplicate records

# %%
# 1. Removing the redundunt rows of data

# Checking redundunt rows of data

wrong_data= dataset['PAGE NO']=='PAGE NO'
dataset[wrong_data]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 15000  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15016  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15032  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15048  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15064  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES
# ...

# %%
# Performing Negation of the wrong dataset and then storing the correct data back in the dataset DataFrame
# This permamnently remove the wrong data from the original dataframe

dataset= dataset[~wrong_data]

# %%
# Dropping columns which are not required for further analysis

dataset.drop(['URL', 'PAGE NO','CITY'], axis =1, inplace =True)
dataset
# Out:
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1438057742.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# ...

# %%
# 2. Removing the Null Records

#Checking for Null records

dataset.isnull().sum()
# Out:
# NAME                  0
# PRICE                 1
# CUSINE_CATEGORY       2
# REGION                1
# CUSINE TYPE           1
# TIMING               66
# RATING_TYPE        1011
# RATING                1
# VOTES                 1
# dtype: int64

# %%
# Checking for a null row

dataset[dataset['PRICE'].isnull()]
# Out:
#       NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 15080       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#       VOTES
# 15080   NaN

# %%
# Droping the above row from the dataset

dataset= dataset.drop(labels=15080, axis=0)

# Replacing the other null records with NA

dataset.fillna('NA', inplace = True)

# Confirming all the null records are correct

dataset.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %%
# 3. Converting the DataTypes of numerical columns to numeric dataype


# Checking for text values in the numerical column before converting it to numeric datatype

dataset[('RATING')].value_counts()
# Out:
# RATING
# -          2360
# 3.5        1094
# 3.4        1036
# 3.6         960
# NEW         953
# 3.3         926
# 3.7         917
# 3.2         801
# 3.8         782
# 3.1         734
# 3.0         622
# 3.9         596
# 2.9         409
# 4.0         408
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# 4.7          13
# 2.3          10
# 2.1           5
# 2.2           4
# 4.8           4
# 4.9           2
# 1.8           1
# 2.0           1
# Name: count, dtype: int64

# %%
# Replacing the text values with '0'

dataset['RATING'].replace(to_replace=['-','NEW','Opening'], value = '0', inplace= True)

# %%
#Checking for text values in the numerical column before converting it to numeric datatype

dataset['VOTES'].value_counts()
# Out:
# VOTES
# -       2360
# NEW      953
# 4        364
# 5        320
# 6        288
#         ...
# 1029       1
# 7350       1
# 964        1
# 585        1
# 1249       1
# Name: count, Length: 1123, dtype: int64

# %%
# Replacing the text values with '0'

dataset['VOTES'].replace(to_replace=['-','NEW','Opening'], value = '0', inplace= True)

# %%
# Changing Data Type of the numerical columns

dataset['PRICE']= dataset['PRICE'].astype('int64')
dataset['RATING']= dataset['RATING'].astype('float64')
dataset['VOTES']=dataset['VOTES'].astype('int64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  int64
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  float64
#  8   VOTES            14138 non-null  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.1+ MB

# %%
# 4. Working with 'Timing' column


dataset['TIMING'].value_counts()
# Out:
# TIMING
# 11am to 11pm(Mon-Sun)                              1192
# 11am to 12midnight(Mon-Sun)                         632
# 12noon to 12midnight(Mon-Sun)                       467
# 11am to 1130pm(Mon-Sun)                             309
# 10am to 10pm(Mon-Sun)                               267
#                                                    ...
# 1130am to 4pm,630pm to 1230AM...                      1
# 12midnight to 5am,12noon to 12midnight(Mon-Sun)       1
# 12midnight to 1230AM,12noon to 4pm,7pm to ...         1
# 12noon to 330pm,630pm to 12midnight...                1
# 8am to 11pm,12midnight to 115am(Mon-Sun)              1
# Name: count, Length: 2551, dtype: int64

# %%
# Splitting the column and storing it in temp_df dataframe

temp_dataset= dataset['TIMING'].str.split('(', n=1, expand= True)
temp_dataset
# Out:
#                                      0                                 1
# 0                      12noon to 130am                          Mon-Sun)
# 1                           2pm to 1am                          Mon-Sun)
# 2                        12noon to 1am                          Mon-Sun)
# 3                      12noon to 130am                          Mon-Sun)
# 4                        1130am to 1am                          Mon-Sun)
# ...                                ...                               ...
# 15075  8am to 11pm,12midnight to 115am                          Mon-Sun)
# 15076                    11am to 230am                          Mon-Sun)
# 15077                     11am to 11pm  Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078                    9am to 1230AM                          Mon-Sun)
# 15079       12noon to 330pm,7pm to 1am                          Mon-Sun)
#
# [14138 rows x 2 columns]

# %%
# Assigning the columns back to the original dataframe

dataset['TIMING']= temp_dataset[0]
dataset['DAYS_OPEN']= temp_dataset[1]
dataset
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# ...                  ...    ...
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15077           PitaBurg    400
# 15078     Uncha Otlawala    300
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# ...

# %%
# Removing the bracket character from Days column

dataset['DAYS_OPEN']=dataset['DAYS_OPEN'].str.replace(r'\(|\)','',regex=True)
dataset.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#             TIMING  RATING_TYPE  RATING  VOTES DAYS_OPEN
# ...

# %%
# Checking for Null records in DAYS_OPEN column

dataset.isnull().sum()
# Out:
# NAME                 0
# PRICE                0
# CUSINE_CATEGORY      0
# REGION               0
# CUSINE TYPE          0
# TIMING               0
# RATING_TYPE          0
# RATING               0
# VOTES                0
# DAYS_OPEN          160
# dtype: int64

# %%
# Replacing the Null values with 'NA'
    
dataset.fillna('NA', inplace= True)

# Checking info of all the columns

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  int64
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  float64
#  8   VOTES            14138 non-null  int64
#  9   DAYS_OPEN        14138 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
# 5.Removing the restaurant records whose Rating or Votes is 0

remove_data= (dataset['RATING']==0.0)| (dataset['VOTES']==0)
dataset[remove_data]
# Out:
#                                 NAME  PRICE  \
# 32     Hotel Annapoorna Refreshments    400
# 34                         Biryani 9    600
# 36                 D Fusion Flavours    350
# 39                      Nation Tadka    400
# 83              Link  Way Restaurant    500
# ...                              ...    ...
# 14998                  Foodies House      0
# 14999                       Khansama      0
# 15010        Earth Cafe @ Waterfield    800
# 15023           How About Some Cream    200
# 15046          Food And Taste Theory    800
#
#                                    CUSINE_CATEGORY  \
# 32                   Maharashtrian,Mughlai,Chinese
# 34                            Biryani,North Indian
# 36                                         Chinese
# 39     North Indian,South Indian,Chinese,Fast Food
# 83                            North Indian,Chinese
# ...                                            ...
# 14998                                      Chinese
# ...

# %%
#Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
#This permamnently remove the wrong data from the original dataframe

dataset=dataset[~remove_data]

# %%
# 6. Working on 'RATING_TYPE' Column

# Checking the unique values in the column

dataset["RATING_TYPE"].value_counts()
# Out:
# RATING_TYPE
# Average          5111
# Good             4330
# Very Good        1137
# Excellent          95
# Poor               47
# Veľmi dobré         6
# Skvělá volba        4
# Dobrze              4
# Bardzo dobrze       3
# Ortalama            2
# Bueno               2
# İyi                 2
# Buono               2
# Dobré               2
# Bom                 2
# Priemer             2
# Průměr              2
# Muito Bom           2
# Promedio            2
# Muy Bueno           1
# Sangat Baik         1
# Média               1
# Biasa               1
# Skvělé              1
# Baik                1
# Çok iyi             1
# Excelente           1
# Velmi dobré         1
# Media               1
# Name: count, dtype: int64

# %%
# Translating the texts into proper English text

dataset['RATING_TYPE'].replace(to_replace='Excelente', value = 'Excellent', inplace= True)
dataset['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'], value = 'Very Good', inplace= True)
dataset['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'], value = 'Good', inplace= True)
dataset['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True)
# Out:
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1437517308.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1437517308.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1437517308.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
# Checking all the values correctly mapped

dataset['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average      5115
# Good         4347
# Very Good    1148
# Excellent      96
# Poor           57
# Very Poor       4
# Name: count, dtype: int64

# %%
# 7. Working on 'REGION' Column

dataset['REGION'].value_counts()
# Out:
# REGION
# Mira Road                            405
# Malad West                           308
# Chembur                              277
# Kharghar                             268
# Borivali West                        264
#                                     ...
# Hotel Emerald-- Juhu                   1
# Trident-- Bandra Kurla Complex         1
# Sea Princess-- Juhu                    1
# Aureole Hotel-- Andheri East           1
# Hotel Satkar Residency-- Majiwada      1
# Name: count, Length: 237, dtype: int64

# %%
# Removing the irrelevant text from the Region column
    
dataset['REGION']=dataset['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)
# Out:
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/281350927.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Removing the West & East from the Region column

dataset['REGION']=dataset['REGION'].str.replace(' West| west| East| east','',regex=True)
value_counts=dataset['REGION'].value_counts()
value_counts
# Out:
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/912230691.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# REGION
# Thane                726
# Mira Road            412
# Andheri              409
# Malad                378
# Kandivali            377
#                     ...
# Flea Bazaar Café       3
# Majiwada               3
# Panvel                 2
# CBD Belapur            1
# Girgaon Chowpatty      1
# Name: count, Length: 101, dtype: int64

# %% [markdown]
# for region, count in value_counts.items():
#     print(f'REGION: {region}, Count: {count}')

# %%
# Replacing Small regions with Known region name
    
dataset['REGION'] = dataset['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area|Mohammad Ali Road|Charni Road|Marine Lines|Kemps Corner|Peddar Road','Andheri', regex= True)
dataset['REGION'] = dataset['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Runwal Green','Mulund',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Kamothe','Sion',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)
# Out:
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1199884452.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1199884452.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/07/ykgp85052b11h5kz22ghn8l40000gn/T/ipykernel_80995/1199884452.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# 8. Removing Duplicate records

# Finding all the duplicate rows

dataset[dataset.duplicated()]
# Out:
#                                 NAME  PRICE  \
# 4064   Sai Sannidhi Restaurant & Bar   1000
# 4068                    Konkan Katta    400
# 4082                  Usmaniya Hotel    600
# 4083                    Gina's Cakes    450
# 4084          Konkanastha Lunch Home    400
# ...                              ...    ...
# 14200      Mezbaan Family Restaurant    350
# 14204               Jyoti Lunch Home    650
# 14253                        On Toes    900
# 14761                    Frosty Farm    400
# 14928               Shree Manu Sagar    300
#
#                             CUSINE_CATEGORY     REGION     CUSINE TYPE  \
# 4064                    North Indian,Konkan    Dahisar   Casual Dining
# 4068          Seafood,Maharashtrian,Malwani   Mahakali     Quick Bites
# 4082                                Mughlai       Fort   Casual Dining
# 4083                                 Bakery  Dombivali            none
# 4084                        Seafood,Malwani    Chakala   Casual Dining
# ...

# %%
# Dropping all the duplicate rows

dataset=dataset.drop_duplicates()

# %% [markdown]
# #  Copying the cleaned data into a new DataFrame

# %%
PP_Zomato_dataset=dataset.copy()
PP_Zomato_dataset
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# ...                  ...    ...
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15077           PitaBurg    400
# 15078     Uncha Otlawala    300
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY       REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...       Bandra
# 1                           Desserts,Ice Cream,Beverages        Mahim
# 2                                          Asian,Chinese         Juhu
# 3                                          Modern Indian       Bandra
# 4                       North Indian,Chinese,Continental       Bandra
# ...                                                  ...          ...
# 15075                     Chinese,Fast Food,North Indian      Andheri
# ...

# %% [markdown]
# # Performing Exploratory Data Analysis

# %% [markdown]
# ### Q1) How many restaurants are in Mumbai for each type of cuisine?

# %%
#pip install -U kaleido

# %%
counts = PP_Zomato_dataset['CUSINE TYPE'].value_counts()
counts
# Out:
# CUSINE TYPE
# Casual Dining     4107
# Quick Bites       3540
# none              1127
# Bakery             537
# Dessert Parlor     431
# Café               320
# Sweet Shop         123
# Beverage Shop       91
# Food Court          50
# Bar                 47
# Dhaba               38
# Fine Dining         35
# Food Truck          30
# Lounge              27
# Pub                 17
# Kiosk               13
# Paan Shop            6
# Confectionery        3
# Bhojanalya           2
# Microbrewery         1
# Irani Cafe           1
# Mess                 1
# Name: count, dtype: int64

# %%
fig= px.histogram(PP_Zomato_dataset, x='CUSINE TYPE', color='CUSINE TYPE',
                  title= 'No. of Restaurants by Cusine Type',
                  labels={'CUSINE TYPE': 'Cusine Type'})

for cuisine_type, count in counts.items():
    fig.add_annotation(
        text=str(count),
        x=cuisine_type,
        y=count,
        showarrow=False,
        font=dict(color='black'),)

fig.show()

# %% [markdown]
# ### Q2) What is the percentage of restaurants by Rating Type in Mumbai?

# %%
rating_type = PP_Zomato_dataset['RATING_TYPE'].value_counts().reset_index()
rating_type.columns = ['RATING_TYPE', 'COUNT OF RESTAURANTS']
rating_type['PERCENTAGE'] = (rating_type['COUNT OF RESTAURANTS'] / rating_type['COUNT OF RESTAURANTS'].sum()) * 100
rating_type
# Out:
#   RATING_TYPE  COUNT OF RESTAURANTS  PERCENTAGE
# 0     Average                  4983   47.245662
# 1        Good                  4263   40.419077
# 2   Very Good                  1145   10.856168
# 3   Excellent                    96    0.910211
# 4        Poor                    56    0.530957
# 5   Very Poor                     4    0.037925

# %%
fig=px.pie(rating_type, names = 'RATING_TYPE', values = 'COUNT OF RESTAURANTS', color = 'RATING_TYPE',
          title= 'Percentage of Restaurants by Rating Types').update_traces(textposition='inside',textinfo='percent+label')
fig.show()

# %% [markdown]
# ### Q3) Which are the Top 10 highest rated Seafood Restaurant in Mumbai?

# %%
seafood_restaurant=  PP_Zomato_dataset[ PP_Zomato_dataset['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_restaurant.sort_values(by='RATING',ascending=False).head(10)
# Out:
#                                           NAME  PRICE  \
# 7104                                Thangabali   1000
# 76                     Ceremonial Kitchen & Co   1000
# 13685                   Maharashtra Lunch Home    600
# 12433                          Quarter Canteen   1100
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
# 884        Rajmanya- Seafood family restaurant    800
# 3380                                 Peco Peco    700
# 9954                        Pi Bar and Kitchen   1600
# 903                                Ferry Wharf   1500
# 915                   Monis Bar and Restaurant   1000
#
#                                          CUSINE_CATEGORY    REGION  \
# 7104      Seafood,South Indian,Mangalorean,Andhra,Kerala      Khar
# 76            Seafood,Maharashtrian,North Indian,Chinese     Thane
# 13685               Maharashtrian,Malwani,Konkan,Seafood  Kharghar
# 12433                       North Indian,Seafood,Chinese    Bandra
# ...

# %% [markdown]
# ### Q4) Which are the best Food Truck in Mumbai?

# %%
best_foodtruck=PP_Zomato_dataset[PP_Zomato_dataset['CUSINE TYPE']=='Food Truck']
best_foodtruck.sort_values(by='RATING', ascending = False).head(3)
# Out:
#                    NAME  PRICE    CUSINE_CATEGORY   REGION CUSINE TYPE  \
# 262   Dumpling Delights    200              Momos  Matunga  Food Truck
# 1017    Street Food Co.    250  Fast Food,Chinese    Virar  Food Truck
# 7922    Honeys Delights    100   Fast Food,Burger    Malad  Food Truck
#
#               TIMING RATING_TYPE  RATING  VOTES              DAYS_OPEN
# 262   430pm to 930pm   Very Good     4.3    212                Mon-Sun
# 1017      6pm to 3am   Very Good     4.1    274                Mon-Sun
# 7922          Closed        Good     3.9     66  Mon,4am to 7amTue-Sun

# %% [markdown]
# ### Q5) Which places have the highest rated restaurant for each Cuisine Type in Mumbai?

# %%
high_rated_restaurants = PP_Zomato_dataset[PP_Zomato_dataset['RATING'] >= 4.5]

# Retrieve the place of the highest-rated restaurants

table =high_rated_restaurants[['NAME','REGION', 'CUSINE TYPE', 'RATING']]
table
# Out:
#                              NAME       REGION     CUSINE TYPE  RATING
# 0                         Hitchki       Bandra   Casual Dining     4.9
# 6                  Persian Darbar        Marol   Casual Dining     4.5
# 7                         Tanatan         Juhu   Casual Dining     4.7
# 9              Plum by Bent Chair  Lower Parel   Casual Dining     4.7
# 10                  Angrezi Dhaba        Dadar             Bar     4.5
# ...                           ...          ...             ...     ...
# 14228  Zaika Crave - Club Aquaria     Borivali   Casual Dining     4.5
# 14234                Cone Culture     Kharghar   Casual Dining     4.6
# 15007                  Dessertino    Kandivali  Dessert Parlor     4.8
# 15051                    Tick-eat       Mulund   Casual Dining     4.5
# 15056             Daftar Goregaon     Goregaon   Casual Dining     4.6
#
# [97 rows x 4 columns]

# %%
fig=px.histogram(high_rated_restaurants,x='REGION',color='CUSINE TYPE',
                title= 'No. of Best Restaurants for Each Cusine Types by Places').update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# ### Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
avrg_price=high_rated_restaurants.groupby(by=['REGION','CUSINE TYPE'])['PRICE'].mean().reset_index()
avrg_price.columns = ['REGION','CUSINE TYPE','MEAN PRICE']
avrg_price.head()
# Out:
#     REGION     CUSINE TYPE  MEAN PRICE
# 0  Andheri             Bar      1600.0
# 1  Andheri            Café       800.0
# 2  Andheri   Casual Dining      1175.0
# 3  Andheri  Dessert Parlor       225.0
# 4  Andheri          Lounge      1700.0

# %%
fig=px.scatter(avrg_price , x= 'REGION',y='MEAN PRICE', color='CUSINE TYPE',symbol = 'CUSINE TYPE',
              title= 'Avg Price Distibution of High Rated Restaurants for Each Cuisine Type').update_traces(marker_size = 6)
fig.show()

# %% [markdown]
# ### Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
cr=PP_Zomato_dataset[PP_Zomato_dataset['CUSINE_CATEGORY'].str.contains('Chinese')]
cr
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 2          Chin Chin Chu   1800
# 4              BKC  DIVE   1200
# 5       Flea Bazaar Café    800
# 6         Persian Darbar   1300
# ...                  ...    ...
# 15071      Lucknow Zaika    500
# 15072     Zuha's Kitchen    400
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY          REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...          Bandra
# 2                                          Asian,Chinese            Juhu
# 4                       North Indian,Chinese,Continental          Bandra
# 5      American,Asian,Street Food,North Indian,Luckno...     Lower Parel
# 6                   Biryani,North Indian,Chinese,Mughlai           Marol
# ...                                                  ...             ...
# ...

# %%
crc = cr.groupby(by='REGION').agg({'NAME':'count', 'PRICE':'mean'})
crc.rename(columns={'NAME':'Chinese Restaurant Count', 'PRICE':'Mean Price'}, inplace=True)
crc=crc.sort_values('Chinese Restaurant Count',ascending=False).head(25)
crc.head()
# Out:
#            Chinese Restaurant Count  Mean Price
# REGION
# Thane                           371  590.983827
# Andheri                         359  622.423398
# Mira Road                       224  553.348214
# Malad                           186  604.032258
# Goregaon                        163  548.773006

# %%
#Create a bar chart
fig = px.bar(crc, x=crc.index, y='Chinese Restaurant Count', labels={'x': 'REGION', 'y': 'Chinese Restaurant Count'},title=f'Chinese Restaurant Count by Location', color='Mean Price',text='Chinese Restaurant Count')

#Customize the text display on the bars
fig.update_traces(texttemplate='%{text}', textposition='outside')
fig.show()

# %% [markdown]
# ### Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
correlation = PP_Zomato_dataset.groupby('CUSINE TYPE')[['PRICE', 'RATING']].corr().iloc[0::2, -1]
correlation
# Out:
# CUSINE TYPE
# Bakery          PRICE    0.123945
# Bar             PRICE    0.290282
# Beverage Shop   PRICE    0.173174
# Bhojanalya      PRICE   -1.000000
# Café            PRICE    0.401321
# Casual Dining   PRICE    0.473607
# Confectionery   PRICE    0.818392
# Dessert Parlor  PRICE    0.194234
# Dhaba           PRICE    0.108422
# Fine Dining     PRICE    0.153549
# Food Court      PRICE    0.025806
# Food Truck      PRICE   -0.015445
# Irani Cafe      PRICE         NaN
# Kiosk           PRICE    0.180643
# Lounge          PRICE    0.307669
# Mess            PRICE         NaN
# Microbrewery    PRICE         NaN
# Paan Shop       PRICE   -0.077152
# Pub             PRICE    0.451411
# Quick Bites     PRICE    0.152220
# Sweet Shop      PRICE    0.089994
# none            PRICE    0.265772
# Name: RATING, dtype: float64

# %%
pr=PP_Zomato_dataset.groupby(['CUSINE TYPE','RATING'])["PRICE"].mean().reset_index()
pr
# Out:
#     CUSINE TYPE  RATING       PRICE
# 0        Bakery     2.7  400.000000
# 1        Bakery     2.8  285.714286
# 2        Bakery     2.9  328.571429
# 3        Bakery     3.0  300.000000
# 4        Bakery     3.1  369.117647
# ..          ...     ...         ...
# 278        none     4.3  683.333333
# 279        none     4.4  555.000000
# 280        none     4.5  420.000000
# 281        none     4.6  687.500000
# 282        none     4.7  350.000000
#
# [283 rows x 3 columns]

# %%
fig=px.line(pr,x='RATING', y= 'PRICE',color='CUSINE TYPE')
fig.show()

# %% [markdown]
# ### Q9) Is there a relation between Region and Price?

# %%
regprice=PP_Zomato_dataset.groupby(['REGION'])["PRICE"].mean().reset_index()
regprice
# Out:
#         REGION       PRICE
# 0       Airoli  452.287582
# 1      Alibaug  665.000000
# 2    Ambernath  514.000000
# 3      Andheri  549.584270
# 4       Bandra  724.945946
# ..         ...         ...
# 70    Vikhroli  480.434783
# 71  Vile Parle  464.457831
# 72       Virar  452.027027
# 73      Wadala  427.500000
# 74       Worli  537.012987
#
# [75 rows x 2 columns]

# %%
fig=px.scatter(regprice,x='REGION', y='PRICE').update_traces(marker_size=6)
fig.show()

# %% [markdown]
# ### Q10) Find the list of Affordable Restaurants?

# %% [markdown]
# #### The criteria for Affordable Restaurants would be:-
#
# #### 1) Low Price 2) High Rated
#
# #### First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.

# %%
max_price= PP_Zomato_dataset['PRICE'].max()
quaterth_price=max_price/4
quaterth_price
# Out:
# 1250.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restaurant

aff_res=PP_Zomato_dataset[['NAME','PRICE','CUSINE_CATEGORY','REGION','CUSINE TYPE']]
aff_res=aff_res[aff_res['PRICE']<=1250]
aff_res.sort_values(by='PRICE',inplace = True)
aff_res
# Out:
#                                                    NAME  PRICE  \
# 6137                                 Sanjog Wine N Dine      5
# 2925                                         Jab We Eat     50
# 9598                                          Ho5 Store     50
# 9589                                   Golden Butterfly    100
# 5916                                  Madhuri Puranpoli    100
# ...                                                 ...    ...
# 2740                                     Peninsula Next   1200
# 5528                                         The Thekka   1200
# 964                                        Bijoli Grill   1250
# 6045  Fabelle at The Chocolate Boutique - ITC Grand ...   1250
# 7301                               SamBar Pub & Kitchen   1250
#
#                                         CUSINE_CATEGORY      REGION  \
# 6137                               North Indian,Chinese       Thane
# 2925  South Indian,North Indian,Maharashtrian,Fast Food     Girgaum
# ...

# %%
# Finding the high rated list of restaurants
    
highrate_res=PP_Zomato_dataset[['NAME','PRICE','CUSINE_CATEGORY','REGION','CUSINE TYPE','RATING']]
highrate_res=highrate_res[highrate_res['RATING']>=4.5]
highrate_res.sort_values(by='RATING',inplace = True)
highrate_res
# Out:
#                               NAME  PRICE  \
# 1675               The Delhi Spice    400
# 9777   Poetry By Love & Cheesecake   1000
# 697               Dhadak Resto Bar   1000
# 711                Shaollin Temple   1000
# 9776                  Burma  Burma   1500
# ...                            ...    ...
# 66                  Downtown China    750
# 9778                      Rajdhani    950
# 15007                   Dessertino    300
# 10669           Trumpet Sky Lounge   1700
# 0                          Hitchki   1200
#
#                                          CUSINE_CATEGORY       REGION  \
# 1675                      Chinese,Fast Food,North Indian     Goregaon
# 9777                                       Cafe,Desserts         Juhu
# 697                     North Indian,Chinese,Continental        Thane
# 711                                         Chinese,Thai  CBD Belapur
# 9776                                       Asian,Burmese         Fort
# ...

# %%
# Merge aff_res & highrate_res to get Affordable Restaurants with low price and high rating

highrate_aff_res= pd.merge(aff_res,highrate_res,how='inner',on=['NAME','REGION'])
highrate_aff_res=highrate_aff_res[['NAME','PRICE_x','CUSINE_CATEGORY_x','REGION','CUSINE TYPE_x']]
highrate_aff_res.rename(columns={'NAME':'NAME','PRICE_x':'PRICE','CUSINE_CATEGORY_x':'CUSINE_CATEGORY','REGION':'REGION','CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)
highrate_aff_res
# Out:
#                              NAME  PRICE  \
# 0   Cake Centre-The Dessert Maker    150
# 1          Curry And Combos Twist    200
# 2                    Moussestruck    200
# 3                    Cone Culture    250
# 4                     Smiley Pops    300
# ..                            ...    ...
# 60         Wild Dining Restaurant   1200
# 61                        Invento   1200
# 62                 Culinary Tales   1200
# 63                        Hitchki   1200
# 64               The Joker Bistro   1200
#
#                                       CUSINE_CATEGORY       REGION  \
# 0                                            Desserts      Andheri
# 1                                North Indian,Chinese      Andheri
# 2                                            Desserts      Andheri
# 3                                            European     Kharghar
# 4               Desserts,Ice Cream,Beverages,Sandwich      Andheri
# ...

# %% [markdown]
# ### Q11) Find the list of most Reliable Restaurants?

# %% [markdown]
# #### The criteria for Affordable Restaurants would be:-
#
# #### 1) Low Price 2) High Rated 3)Large No. of votes
#
# #### First two steps has been already carried out. So next step will be to  find the restaurants with Votes greater than Mean of Votes.

# %%
mean_votes= PP_Zomato_dataset['VOTES'].mean()
mean_votes
# Out:
# 177.2656679624538

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote

mean_res=PP_Zomato_dataset[['NAME','PRICE','CUSINE_CATEGORY','REGION','CUSINE TYPE','VOTES']]
mean_res=mean_res[mean_res['VOTES']>177]
mean_res.sort_values(by='VOTES',inplace = True)
mean_res
# Out:
#                                      NAME  PRICE  \
# 4194                  Sai Sagar Veg Treat    500
# 884   Rajmanya- Seafood family restaurant    800
# 3914                             Ice Cafe    500
# 7897                     Konkan Lajjatdar    500
# 3828     Frozen Delight -The Dessert Cafe    250
# ...                                   ...    ...
# 8539                   Leopold Cafe & Bar   1600
# 1251                         Joey's Pizza    800
# 5337         Chili's American Grill & Bar   1400
# 3751                         Prithvi Cafe    700
# 8897                              Candies    700
#
#                                         CUSINE_CATEGORY    REGION  \
# 4194  North Indian,South Indian,Chinese,Fast Food,Be...    Kalyan
# 884                        Maharashtrian,Konkan,Seafood     Vashi
# 3914                Fast Food,Ice Cream,Beverages,Pizza  Borivali
# 7897   Seafood,Biryani,Beverages,Chinese,Malwani,Konkan   Andheri
# ...

# %% [markdown]
#
# ## Criteria for most reliable, highest rated and affordable restaurants:-
#
# #### Cost is below or =1250, Rating is above 4.5 & Votes are above 177
#
# #### This is obtained by merging highrate_aff_res & mean_res

# %%
reliable_res= pd.merge(mean_res,highrate_aff_res,how='inner',on=['NAME','REGION'])
reliable_res=reliable_res[['NAME','PRICE_x','CUSINE_CATEGORY_x','REGION','CUSINE TYPE_x']]
reliable_res.rename(columns={'NAME':'NAME','PRICE_x':'PRICE','CUSINE_CATEGORY_x':'CUSINE_CATEGORY','REGION':'REGION','CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)
reliable_res
# Out:
#                                    NAME  PRICE  \
# 0   Rajmanya- Seafood family restaurant    800
# 1                        Fresh Food Co.    500
# 2                            Dessertino    300
# 3                               Invento   1200
# 4                Maharashtra Lunch Home    600
# 5                              Regano's    600
# 6                       Big Bang Cuurry    350
# 7                           Sandy's Den   1000
# 8                     Angrezi Patiyalaa   1200
# 9                                 Maezo   1000
# 10                         Tossin Pizza    900
# 11                    Little West Pizza    600
# 12              Ceremonial Kitchen & Co   1000
# 13                         Moussestruck    200
# 14                      Daftar Goregaon    750
# 15          Poetry By Love & Cheesecake   1000
# 16                         Makhan Singh    800
# 17                     The Joker Bistro   1200
# 18                         Cone Culture    250
# ...
